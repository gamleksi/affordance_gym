# %%
import os
import numpy as np
import pandas as pd
from motion_planning.utils import parse_arguments, VAED_MODELS_PATH
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/aleksi/.local/lib/python2.7/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 2, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)

# %%
kinect_experiments_path = '/home/aleksi/mujoco_ws/src/motion_planning/kinect_experiments/full_experiments'
csv_path = os.path.join(kinect_experiments_path, 'cup_log.csv')
csv_path
# Out:
# '/home/aleksi/mujoco_ws/src/motion_planning/kinect_experiments/full_experiments/cup_log.csv'

# %%
data = pd.read_csv(csv_path)
data.head(9)
# Out:
#     cup_type  cup_x  cup_y  end_pose_x  end_pose_y  distance    azimuth  \
# 0   karol_v1    0.4  -0.15    0.424678   -0.048703  1.175362 -89.868640
# 1  rocket_v1    0.4  -0.15    0.426435   -0.074098  1.175362 -89.868640
# 2  subway_v1    0.4  -0.15    0.415458   -0.089161  1.175362 -89.868640
# 3    blue_v1    0.4  -0.15    0.413260   -0.106917  1.175362 -89.868640
# 4  mirror_v1    0.4  -0.15    0.429572   -0.039540  1.177447 -89.749123
# 5     red_v1    0.4  -0.15    0.425114   -0.049328  1.177447 -89.749123
# 6    gray_v1    0.4  -0.15    0.424208   -0.067746  1.177447 -89.749123
# 7     can_v1    0.4  -0.15    0.433721   -0.072570  1.177447 -89.749123
# 8  yellow_v1    0.4  -0.15    0.438390   -0.010239  1.174933 -89.865313
#
#    elevation      roll  kinect_lookat_x  kinect_lookat_y  kinect_lookat_z
# 0 -29.867427 -0.001022         0.700107        -0.009858              0.0
# 1 -29.867427 -0.001022         0.700107        -0.009858              0.0
# ...

# %%
# a Karol cup
cup_name = 'karol'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['karol_v1', 'karol_v2', 'karol_v3', 'karol_v4'], dtype=object))
# ('avg_mean:', 0.08491929)

# %%
# a yellow cup
cup_name = 'red'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['red_v1', 'red_v2', 'red_v3', 'red_v4', 'red_v5'], dtype=object))
# ('avg_mean:', 0.09526082)

# %%
# a yellow cup
cup_name = 'gray'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['gray_v1', 'gray_v2', 'gray_v3', 'gray_v4', 'gray_v5'],
#       dtype=object))
# ('avg_mean:', 0.0781696)

# %%
# a yellow cup
cup_name = 'subway'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['subway_v1', 'subway_v2', 'subway_v3', 'subway'], dtype=object))
# ('avg_mean:', 0.06030293)

# %%
# a yellow cup
cup_name = 'mirror'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['mirror_v1', 'mirror_v2', 'mirror_v3', 'mirror_v4', 'mirror_v5'],
#       dtype=object))
# ('avg_mean:', 0.071930386)

# %%
# a yellow cup
cup_name = 'blue'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['blue_v1', 'blue_v2', 'blue_v3', 'blue_v4', 'blue_v5'],
#       dtype=object))
# ('avg_mean:', 0.049230523)

# %%
# a yellow cup
cup_name = 'can'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['can_v1', 'can_v2', 'can_v4', 'can_v5'], dtype=object))
# ('avg_mean:', 0.07592136)

# %%
# a yellow cup
cup_name = 'rocket'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['rocket_v1', 'rocket_v2', 'rocket_v3', 'rocket_v4', 'rocket_v5'],
#       dtype=object))
# ('avg_mean:', 0.058474578)

# %%
# a yellow cup
cup_name = 'yellow'

arr  = data.values

cup_indices = np.array([cup_name in s for s in arr[:,0]])

print('cup names', arr[:, 0][cup_indices])

# cup_poses = np.array([]

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

#distances = np.linalg.norm(real_poses - pred_poses, axis=0)
print('avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())

plt.figure(figsize=(5, 10))
plt.scatter(real_poses[:,0], real_poses[:,1], c='r')
plt.scatter(pred_poses[:,0], pred_poses[:,1], c='b')
# Out:
# ('cup names', array(['yellow_v1', 'yellow_v2', 'yellow_v4', 'yellow_v5', 'yellow_6'],
#       dtype=object))
# ('avg_mean:', 0.13363644)

# %%
def get_poses(cup_name):

    cup_indices = np.array([cup_name in s for s in arr[:,0]])

    # print('cup names', arr[:, 0][cup_indices])
    real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
    pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

    #distances = np.linalg.norm(real_poses - pred_poses, axis=0)
    
    return real_poses, pred_poses

# %%
cup_names = ['rocket', 'karol', 'gray', 'can', 'blue', 'subway', 'yellow', 'mirror', 'red']
len(cup_names)
# Out:
# 9

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=[30, 30])

for i, cup_name in enumerate(cup_names):
    ax = axes[int(i/3)][i%3]
    
    real_poses, pred_poses = get_poses(cup_name)
    ax.scatter(real_poses[:, 0], real_poses[:, 1], c='r', label='real')
    ax.scatter(pred_poses[:, 0], pred_poses[:, 1], c='b', label='pred')
    ax.set_title(cup_name)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()
# Out:
# ('rocket', 'avg_mean:', 0.058474578)
# ('karol', 'avg_mean:', 0.08491929)
# ('gray', 'avg_mean:', 0.0781696)
# ('can', 'avg_mean:', 0.07592136)
# ('blue', 'avg_mean:', 0.049230523)
# ('subway', 'avg_mean:', 0.06030293)
# ('yellow', 'avg_mean:', 0.13363644)
# ('mirror', 'avg_mean:', 0.071930386)
# ('red', 'avg_mean:', 0.09526082)

# %%
# Yellow is ignored as it produced poor performance
cup_name = 'yellow'
cup_indices = np.array([cup_name not in s for s in arr[:,0]])

real_poses = np.array(arr[:, 1:3][cup_indices], dtype=np.float32)
pred_poses = np.array(arr[:, 3:5][cup_indices], dtype=np.float32)

avg_x_distance = (real_poses[:, 0] - pred_poses[:, 0]).mean()
print('mean', avg_x_distance, 'var', (real_poses[:, 0] - pred_poses[:, 0]).var())

avg_y_distance = (real_poses[:, 1] - pred_poses[:, 1]).mean()
print('mean', avg_y_distance, 'var', (real_poses[:, 1] - pred_poses[:, 1]).var())
# Out:
# ('mean', -0.026596148, 'var', 7.124042e-05)
# ('mean', -0.06522062, 'var', 0.0005627411)

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=[30, 30])
for i, cup_name in enumerate(cup_names):
    ax = axes[int(i/3)][i%3]
    
    real_poses, pred_poses = get_poses(cup_name)
    
    pred_poses[:, 0] += avg_x_distance
    pred_poses[:, 1] += avg_y_distance
    
    print(cup_name, 'avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())
    
    ax.scatter(real_poses[:, 0], real_poses[:, 1], c='r', label='real')
    ax.scatter(pred_poses[:, 0], pred_poses[:, 1], c='b', label='pred')
    ax.set_title(cup_name)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()
# Out:
# ('rocket', 'avg_mean:', 0.017587762)
# ('karol', 'avg_mean:', 0.022808105)
# ('gray', 'avg_mean:', 0.014844157)
# ('can', 'avg_mean:', 0.013522877)
# ('blue', 'avg_mean:', 0.022934008)
# ('subway', 'avg_mean:', 0.014875778)
# ('yellow', 'avg_mean:', 0.07198555)
# ('mirror', 'avg_mean:', 0.03575661)
# ('red', 'avg_mean:', 0.031856358)

# %%
import numpy as np
kinect_debug_results = '/home/aleksi/mujoco_ws/src/motion_planning/scripts/results.npy'

cup_poses, end_poses = np.load(kinect_debug_results)

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=[30, 30])

distances = []
for i, cup_name in enumerate(cup_names):
    ax = axes[int(i/3)][i%3]

    cup_indices = np.array([cup_name in s for s in arr[:, 0]])
    real_poses = cup_poses[cup_indices]
    pred_poses = end_poses[cup_indices]
    
    # pred_poses[:, 0] += avg_x_distance
    # pred_poses[:, 1] += avg_y_distance
    
    distance = np.linalg.norm(real_poses - pred_poses, axis=1).mean()
    print(cup_name, 'avg_mean:', distance)
    distances.append(distance)
    ax.scatter(real_poses[:, 0], real_poses[:, 1], c='r', label='real')
    ax.scatter(pred_poses[:, 0], pred_poses[:, 1], c='b', label='pred')
    ax.set_title(cup_name)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()
    
print('mean distance: ', np.mean(distances))
# Out:
# ('rocket', 'avg_mean:', 0.009176366)
# ('karol', 'avg_mean:', 0.026781384)
# ('gray', 'avg_mean:', 0.016627813)
# ('can', 'avg_mean:', 0.017225627)
# ('blue', 'avg_mean:', 0.026448261)
# ('subway', 'avg_mean:', 0.011316182)
# ('yellow', 'avg_mean:', 0.030885044)
# ('mirror', 'avg_mean:', 0.023601014)
# ('red', 'avg_mean:', 0.036475223)
# ('mean distance: ', 0.022059657)

# %%
# Yellow is ignored as it produced poor performance
cup_name = 'yellow'
cup_indices = np.array([cup_name not in s for s in arr[:,0]])

cup_name = 'mirror'
cup_indices = np.array([cup_name not in s for s in arr[:,0]]) * cup_indices

cup_name = 'red'
cup_indices = np.array([cup_name not in s for s in arr[:,0]]) * cup_indices

real_poses = cup_poses[cup_indices]
pred_poses = end_poses[cup_indices]

asd = real_poses[:, 0] - pred_poses[:, 0]

avg_x_distance = (real_poses[:, 0] - pred_poses[:, 0]).mean()
print('mean', avg_x_distance, 'var', (real_poses[:, 0] - pred_poses[:, 0]).var())

avg_y_distance = (real_poses[:, 1] - pred_poses[:, 1]).mean()
print('mean', avg_y_distance, 'var', (real_poses[:, 1] - pred_poses[:, 1]).var())
# Out:
# ('mean', -0.0009526688, 'var', 3.971537e-05)
# ('mean', 0.008494787, 'var', 0.0003939086)

# %%
# asd = real_poses[:, 0] - pred_poses[:, 0]
#asd.sort()
#asd

# Yellow is ignored as it produced poor performance
cup_name = 'yellow'
cup_indices = np.array([cup_name not in s for s in arr[:,0]])

cup_name = 'mirror'
cup_indices = np.array([cup_name not in s for s in arr[:,0]]) * cup_indices

cup_name = 'red'
cup_indices = np.array([cup_name not in s for s in arr[:,0]]) * cup_indices

real_poses = cup_poses[cup_indices]
pred_poses = end_poses[cup_indices]

x_distances = real_poses[:, 0] - pred_poses[:, 0]
x_distances.sort()
x_distances = x_distances[4:]

avg_x_distance = x_distances.mean()

print('mean', avg_x_distance, 'var', x_distances.var())

y_distances = real_poses[:, 1] - pred_poses[:, 1]
y_distances.sort()
y_distances = y_distances[14:]

avg_y_distance = y_distances.mean()

print('y mean', avg_y_distance, 'y var', y_distances.var())
# Out:
# ('mean', 0.0007257112, 'var', 1.8882227e-05)
# ('y mean', 0.020148996, 'y var', 0.000103875806)

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=[30, 30])

distances = []
for i, cup_name in enumerate(cup_names):
    ax = axes[int(i/3)][i%3]

    cup_indices = np.array([cup_name in s for s in arr[:, 0]])
    real_poses = cup_poses[cup_indices]
    pred_poses = end_poses[cup_indices]
    
    # pred_poses[:, 0] += avg_x_distance
    # pred_poses[:, 1] += avg_y_distance
    
    print(cup_name, 'avg_mean:', np.linalg.norm(real_poses - pred_poses, axis=1).mean())
    distances.append(np.linalg.norm(real_poses - pred_poses, axis=1).mean())
    ax.scatter(real_poses[:, 0], real_poses[:, 1], c='r', label='real')
    ax.scatter(pred_poses[:, 0], pred_poses[:, 1], c='b', label='pred')
    ax.set_title(cup_name)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()
    
print('mean distance: ', np.mean(distances))
# Out:
# ('rocket', 'avg_mean:', 0.017910756)
# ('karol', 'avg_mean:', 0.018361945)
# ('gray', 'avg_mean:', 0.012191777)
# ('can', 'avg_mean:', 0.013635492)
# ('blue', 'avg_mean:', 0.023589056)
# ('subway', 'avg_mean:', 0.018913615)
# ('yellow', 'avg_mean:', 0.029612655)
# ('mirror', 'avg_mean:', 0.029233241)
# ('red', 'avg_mean:', 0.020724062)
# ('mean distance: ', 0.020463623)
